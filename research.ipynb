# %%
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
processor = TrOCRProcessor.from_pretrained("raxtemur/trocr-base-ru")  # русская версия
model = VisionEncoderDecoderModel.from_pretrained("raxtemur/trocr-base-ru")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
from PIL import Image
image = Image.open("dataset/receipt.jpg")
pixel_values = processor(images=image, return_tensors="pt").pixel_values
generated_ids = model.generate(pixel_values)
text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

# %%
text
# Out:
# 'УЕФА'

# %%
import cv2
import pytesseract
from pytesseract import Output

img = cv2.imread('dataset/receipt.jpg', cv2.IMREAD_GRAYSCALE)
# Предобработка: порог, шумоподавление
th = cv2.threshold(img, 150, 255, cv2.THRESH_BINARY)[1]
d = pytesseract.image_to_data(th, output_type=Output.DICT)
items = []
for i, word in enumerate(d['text']):
    text = word.strip()
    if text and any(c.isdigit() for c in text):
        x,y,w,h = d['left'][i], d['top'][i], d['width'][i], d['height'][i]
        items.append({'word': text, 'bbox': (x,y,w,h)})
# Постобработка: группировка слов в строки и поиск "название — цена"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\STUDY\finopolis\venv\Lib\site-packages\pytesseract\pytesseract.py:451, in get_tesseract_version()
#     450 try:
# --> 451     output = subprocess.check_output(
#     452         [tesseract_cmd, '--version'],
#     453         stderr=subprocess.STDOUT,
#     454         env=environ,
#     455         stdin=subprocess.DEVNULL,
#     456     )
#     457 except OSError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] Не удается найти указанный файл
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[5], line 8
#       6 # Предобработка: порог, шумоподавление
#       7 th = cv2.threshold(img, 150, 255, cv2.THRESH_BINARY)[1]
# ----> 8 d = pytesseract.image_to_data(th, output_type=Output.DICT)
#       9 items = []
#      10 for i, word in enumerate(d['text']):
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\pytesseract\pytesseract.py:590, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     576 def image_to_data(
#     577     image,
#     578     lang=None,
#    (...)    583     pandas_config=None,
#     584 ):
#     585     """
#     586     Returns string containing box boundaries, confidences,
#     587     and other information. Requires Tesseract 3.05+
#     588     """
# --> 590     if get_tesseract_version(cached=True) < TESSERACT_MIN_VERSION:
#     591         raise TSVNotSupported()
#     593     config = f'-c tessedit_create_tsv=1 {config.strip()}'
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\pytesseract\pytesseract.py:163, in run_once.<locals>.wrapper(*args, **kwargs)
#     160 @wraps(func)
#     161 def wrapper(*args, **kwargs):
#     162     if not kwargs.pop('cached', False) or wrapper._result is wrapper:
# --> 163         wrapper._result = func(*args, **kwargs)
#     164     return wrapper._result
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\pytesseract\pytesseract.py:458, in get_tesseract_version()
#     451     output = subprocess.check_output(
#     452         [tesseract_cmd, '--version'],
#     453         stderr=subprocess.STDOUT,
#     454         env=environ,
#     455         stdin=subprocess.DEVNULL,
#     456     )
#     457 except OSError:
# --> 458     raise TesseractNotFoundError()
#     460 raw_version = output.decode(DEFAULT_ENCODING)
#     461 str_version, *_ = raw_version.lstrip(string.printable[10:]).partition(' ')
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
import requests

API_KEY = 'helloworld'  # бесплатный ключ OCR.space
def ocr_receipt(path):
    with open(path, 'rb') as f:
        r = requests.post(
            'https://api.ocr.space/parse/image',
            files={'file': f},
            data={'apikey': API_KEY, 
                  'language': 'rus', 
                  'OCREngine': 1,           # обязательный параметр для новых языков
                  'isOverlayRequired': True}
        )
    return r.json()

data = ocr_receipt('dataset/receipt.jpg')
for entry in data['ParsedResults'][0]['TextOverlay']['Lines']:
    print(entry['LineText'], entry['Words'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 16
#       6         r = requests.post(
#       7             'https://api.ocr.space/parse/image',
#       8             files={'file': f},
#    (...)     12                   'isOverlayRequired': True}
#      13         )
#      14     return r.json()
# ---> 16 data = ocr_receipt('dataset/receipt.jpg')
#      17 for entry in data['ParsedResults'][0]['TextOverlay']['Lines']:
#      18     print(entry['LineText'], entry['Words'])
#
# Cell In[18], line 6, in ocr_receipt(path)
#       4 def ocr_receipt(path):
#       5     with open(path, 'rb') as f:
# ----> 6         r = requests.post(
#       7             'https://api.ocr.space/parse/image',
#       8             files={'file': f},
#       9             data={'apikey': API_KEY,
#      10                   'language': 'rus',
#      11                   'OCREngine': 3,           # обязательный параметр для новых языков
#      12                   'isOverlayRequired': True}
#      13         )
#      14     return r.json()
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\STUDY\finopolis\venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data
# Out:
# {'OCRExitCode': 3,
#  'IsErroredOnProcessing': True,
#  'ErrorMessage': ['File failed validation. File size exceeds the maximum permissible file size limit of 1024 KB'],
#  'ErrorDetails': '',
#  'ProcessingTimeInMilliseconds': '15'}

# %%
data['ParsedResults'][0]['TextOverlay']['Lines']
# Out:
# [{'LineText': '000"nponropr"',
#   'Words': [{'WordText': '000"nponropr"',
#     'Left': 429.0,
#     'Top': 113.0,
#     'Height': 19.0,
#     'Width': 136.0}],
#   'MaxHeight': 19.0,
#   'MinTop': 113.0},
#  {'LineText': '690033. r 8naagoocT0K,np-KT',
#   'Words': [{'WordText': '690033.',
#     'Left': 270.0,
#     'Top': 121.0,
#     'Height': 18.0,
#     'Width': 55.0},
#    {'WordText': 'r',
#     'Left': 330.0,
#     'Top': 129.0,
#     'Height': 10.0,
#     'Width': 6.0},
#    {'WordText': '8naagoocT0K,np-KT',
#     'Left': 340.0,
#     'Top': 128.0,
#     'Height': 24.0,
#     'Width': 146.0}],
#   'MaxHeight': 24.0,
#   'MinTop': 121.0},
#  {'LineText': 'KACCOBbtg 142',
#   'Words': [{'WordText': 'KACCOBbtg',
#     'Left': 371.0,
#     'Top': 154.0,
#     'Height': 18.0,
#     'Width': 65.0},
#    {'WordText': '142',
#     'Left': 478.0,
#     'Top': 159.0,
#     'Height': 12.0,
#     'Width': 24.0}],
#   'MaxHeight': 18.0,
#   'MinTop': 154.0},
#  {'LineText': '00109511"',
#   'Words': [{'WordText': '00109511"',
#     'Left': 250.0,
#     'Top': 185.0,
#     'Height': 17.0,
#     'Width': 67.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 185.0},
#  {'LineText': '01792110T',
#   'Words': [{'WordText': '01792110T',
#     'Left': 250.0,
#     'Top': 220.0,
#     'Height': 17.0,
#     'Width': 66.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 220.0},
#  {'LineText': '01792110T',
#   'Words': [{'WordText': '01792110T',
#     'Left': 249.0,
#     'Top': 239.0,
#     'Height': 17.0,
#     'Width': 67.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 239.0},
#  {'LineText': '198822111t _',
#   'Words': [{'WordText': '198822111t',
#     'Left': 248.0,
#     'Top': 292.0,
#     'Height': 16.0,
#     'Width': 66.0},
#    {'WordText': '_',
#     'Left': 318.0,
#     'Top': 307.0,
#     'Height': 1.0,
#     'Width': 2.0}],
#   'MaxHeight': 16.0,
#   'MinTop': 292.0},
#  {'LineText': 'oasooeun.',
#   'Words': [{'WordText': 'oasooeun.',
#     'Left': 246.0,
#     'Top': 309.0,
#     'Height': 17.0,
#     'Width': 73.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 309.0},
#  {'LineText': '121403un .',
#   'Words': [{'WordText': '121403un',
#     'Left': 247.0,
#     'Top': 328.0,
#     'Height': 15.0,
#     'Width': 64.0},
#    {'WordText': '.',
#     'Left': 317.0,
#     'Top': 341.0,
#     'Height': 3.0,
#     'Width': 1.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 328.0},
#  {'LineText': '181207ujT .',
#   'Words': [{'WordText': '181207ujT',
#     'Left': 246.0,
#     'Top': 347.0,
#     'Height': 15.0,
#     'Width': 66.0},
#    {'WordText': '.',
#     'Left': 316.0,
#     'Top': 359.0,
#     'Height': 3.0,
#     'Width': 2.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 347.0},
#  {'LineText': '[M+joa91 BOJIA H uS. 77',
#   'Words': [{'WordText': '[M+joa91',
#     'Left': 330.0,
#     'Top': 190.0,
#     'Height': 19.0,
#     'Width': 62.0},
#    {'WordText': 'BOJIA',
#     'Left': 403.0,
#     'Top': 197.0,
#     'Height': 13.0,
#     'Width': 32.0},
#    {'WordText': 'H',
#     'Left': 508.0,
#     'Top': 192.0,
#     'Height': 11.0,
#     'Width': 9.0},
#    {'WordText': 'uS.',
#     'Left': 527.0,
#     'Top': 192.0,
#     'Height': 14.0,
#     'Width': 27.0},
#    {'WordText': '77',
#     'Left': 559.0,
#     'Top': 195.0,
#     'Height': 12.0,
#     'Width': 16.0}],
#   'MaxHeight': 19.0,
#   'MinTop': 190.0},
#  {'LineText': '9.99',
#   'Words': [{'WordText': '9.99',
#     'Left': 542.0,
#     'Top': 211.0,
#     'Height': 14.0,
#     'Width': 32.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 211.0},
#  {'LineText': '[M4)807G CB 139 90',
#   'Words': [{'WordText': '[M4)807G',
#     'Left': 329.0,
#     'Top': 226.0,
#     'Height': 19.0,
#     'Width': 64.0},
#    {'WordText': 'CB',
#     'Left': 500.0,
#     'Top': 226.0,
#     'Height': 13.0,
#     'Width': 16.0},
#    {'WordText': '139',
#     'Left': 526.0,
#     'Top': 228.0,
#     'Height': 13.0,
#     'Width': 23.0},
#    {'WordText': '90',
#     'Left': 558.0,
#     'Top': 230.0,
#     'Height': 12.0,
#     'Width': 16.0}],
#   'MaxHeight': 19.0,
#   'MinTop': 226.0},
#  {'LineText': '["+17732 CB 139.90',
#   'Words': [{'WordText': '["+17732',
#     'Left': 328.0,
#     'Top': 244.0,
#     'Height': 18.0,
#     'Width': 64.0},
#    {'WordText': 'CB',
#     'Left': 499.0,
#     'Top': 244.0,
#     'Height': 13.0,
#     'Width': 17.0},
#    {'WordText': '139.90',
#     'Left': 525.0,
#     'Top': 246.0,
#     'Height': 14.0,
#     'Width': 49.0}],
#   'MaxHeight': 18.0,
#   'MinTop': 244.0},
#  {'LineText': '[M•J2661 KBAC',
#   'Words': [{'WordText': '[M•J2661',
#     'Left': 327.0,
#     'Top': 262.0,
#     'Height': 17.0,
#     'Width': 62.0},
#    {'WordText': 'KBAC',
#     'Left': 400.0,
#     'Top': 263.0,
#     'Height': 13.0,
#     'Width': 32.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 262.0},
#  {'LineText': 'HVIBoro',
#   'Words': [{'WordText': 'HVIBoro',
#     'Left': 440.0,
#     'Top': 277.0,
#     'Height': 14.0,
#     'Width': 50.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 277.0},
#  {'LineText': '3HEPCE',
#   'Words': [{'WordText': '3HEPCE',
#     'Left': 465.0,
#     'Top': 296.0,
#     'Height': 12.0,
#     'Width': 49.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 296.0},
#  {'LineText': "CANDETk'l' bVMAXHb'E",
#   'Words': [{'WordText': "CANDETk'l'",
#     'Left': 332.0,
#     'Top': 314.0,
#     'Height': 14.0,
#     'Width': 65.0},
#    {'WordText': "bVMAXHb'E",
#     'Left': 405.0,
#     'Top': 312.0,
#     'Height': 13.0,
#     'Width': 67.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 312.0},
#  {'LineText': 'canot-TK1/ BJIAHHblE T',
#   'Words': [{'WordText': 'canot-TK1/',
#     'Left': 331.0,
#     'Top': 331.0,
#     'Height': 14.0,
#     'Width': 65.0},
#    {'WordText': 'BJIAHHblE',
#     'Left': 405.0,
#     'Top': 330.0,
#     'Height': 13.0,
#     'Width': 58.0},
#    {'WordText': 'T',
#     'Left': 507.0,
#     'Top': 331.0,
#     'Height': 12.0,
#     'Width': 6.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 330.0},
#  {'LineText': 'C qECH0kOM 3SO',
#   'Words': [{'WordText': 'C',
#     'Left': 396.0,
#     'Top': 349.0,
#     'Height': 12.0,
#     'Width': 8.0},
#    {'WordText': 'qECH0kOM',
#     'Left': 413.0,
#     'Top': 348.0,
#     'Height': 12.0,
#     'Width': 67.0},
#    {'WordText': '3SO',
#     'Left': 490.0,
#     'Top': 348.0,
#     'Height': 13.0,
#     'Width': 25.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 348.0},
#  {'LineText': 'nE[1ÉLKA Y36EKCKAR 350r',
#   'Words': [{'WordText': 'nE[1ÉLKA',
#     'Left': 330.0,
#     'Top': 366.0,
#     'Height': 15.0,
#     'Width': 58.0},
#    {'WordText': 'Y36EKCKAR',
#     'Left': 397.0,
#     'Top': 365.0,
#     'Height': 14.0,
#     'Width': 74.0},
#    {'WordText': '350r',
#     'Left': 481.0,
#     'Top': 365.0,
#     'Height': 13.0,
#     'Width': 32.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 365.0},
#  {'LineText': '14908',
#   'Words': [{'WordText': '14908',
#     'Left': 525.0,
#     'Top': 264.0,
#     'Height': 13.0,
#     'Width': 48.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 264.0},
#  {'LineText': '148.',
#   'Words': [{'WordText': '148.',
#     'Left': 525.0,
#     'Top': 281.0,
#     'Height': 12.0,
#     'Width': 28.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 281.0},
#  {'LineText': '11990',
#   'Words': [{'WordText': '11990',
#     'Left': 525.0,
#     'Top': 298.0,
#     'Height': 13.0,
#     'Width': 48.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 298.0},
#  {'LineText': '86 sg',
#   'Words': [{'WordText': '86',
#     'Left': 532.0,
#     'Top': 332.0,
#     'Height': 12.0,
#     'Width': 16.0},
#    {'WordText': 'sg',
#     'Left': 552.0,
#     'Top': 333.0,
#     'Height': 12.0,
#     'Width': 21.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 332.0},
#  {'LineText': '65.90',
#   'Words': [{'WordText': '65.90',
#     'Left': 532.0,
#     'Top': 349.0,
#     'Height': 14.0,
#     'Width': 42.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 349.0},
#  {'LineText': '56.90',
#   'Words': [{'WordText': '56.90',
#     'Left': 532.0,
#     'Top': 367.0,
#     'Height': 13.0,
#     'Width': 41.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 367.0},
#  {'LineText': '259.90',
#   'Words': [{'WordText': '259.90',
#     'Left': 523.0,
#     'Top': 402.0,
#     'Height': 13.0,
#     'Width': 51.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 402.0},
#  {'LineText': '229.90',
#   'Words': [{'WordText': '229.90',
#     'Left': 523.0,
#     'Top': 420.0,
#     'Height': 13.0,
#     'Width': 51.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 420.0},
#  {'LineText': '77.38',
#   'Words': [{'WordText': '77.38',
#     'Left': 531.0,
#     'Top': 438.0,
#     'Height': 13.0,
#     'Width': 43.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 438.0},
#  {'LineText': '90.39',
#   'Words': [{'WordText': '90.39',
#     'Left': 531.0,
#     'Top': 456.0,
#     'Height': 13.0,
#     'Width': 42.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 456.0},
#  {'LineText': '34.38',
#   'Words': [{'WordText': '34.38',
#     'Left': 531.0,
#     'Top': 475.0,
#     'Height': 13.0,
#     'Width': 42.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 475.0},
#  {'LineText': '189.90',
#   'Words': [{'WordText': '189.90',
#     'Left': 523.0,
#     'Top': 493.0,
#     'Height': 13.0,
#     'Width': 50.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 493.0},
#  {'LineText': '99',
#   'Words': [{'WordText': '99',
#     'Left': 706.0,
#     'Top': 220.0,
#     'Height': 12.0,
#     'Width': 16.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 220.0},
#  {'LineText': '30',
#   'Words': [{'WordText': '30',
#     'Left': 706.0,
#     'Top': 376.0,
#     'Height': 11.0,
#     'Width': 16.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 376.0},
#  {'LineText': '69.90',
#   'Words': [{'WordText': '69.90',
#     'Left': 532.0,
#     'Top': 385.0,
#     'Height': 12.0,
#     'Width': 41.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 385.0},
#  {'LineText': '+1',
#   'Words': [{'WordText': '+1',
#     'Left': 616.0,
#     'Top': 301.0,
#     'Height': 13.0,
#     'Width': 15.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 301.0},
#  {'LineText': '*0.142',
#   'Words': [{'WordText': '*0.142',
#     'Left': 584.0,
#     'Top': 403.0,
#     'Height': 14.0,
#     'Width': 48.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 403.0},
#  {'LineText': '*0.25B',
#   'Words': [{'WordText': '*0.25B',
#     'Left': 584.0,
#     'Top': 421.0,
#     'Height': 13.0,
#     'Width': 49.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 421.0},
#  {'LineText': '*0.346',
#   'Words': [{'WordText': '*0.346',
#     'Left': 584.0,
#     'Top': 492.0,
#     'Height': 14.0,
#     'Width': 48.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 492.0},
#  {'LineText': '77',
#   'Words': [{'WordText': '77',
#     'Left': 706.0,
#     'Top': 203.0,
#     'Height': 11.0,
#     'Width': 16.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 203.0},
#  {'LineText': '2139 90',
#   'Words': [{'WordText': '2139',
#     'Left': 665.0,
#     'Top': 254.0,
#     'Height': 11.0,
#     'Width': 32.0},
#    {'WordText': '90',
#     'Left': 705.0,
#     'Top': 255.0,
#     'Height': 11.0,
#     'Width': 16.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 254.0},
#  {'LineText': '•-149',
#   'Words': [{'WordText': '•-149',
#     'Left': 665.0,
#     'Top': 271.0,
#     'Height': 12.0,
#     'Width': 31.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 271.0},
#  {'LineText': '•148.79',
#   'Words': [{'WordText': '•148.79',
#     'Left': 665.0,
#     'Top': 288.0,
#     'Height': 13.0,
#     'Width': 56.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 288.0},
#  {'LineText': '=119_',
#   'Words': [{'WordText': '=119_',
#     'Left': 664.0,
#     'Top': 306.0,
#     'Height': 11.0,
#     'Width': 37.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 306.0},
#  {'LineText': '98',
#   'Words': [{'WordText': '98',
#     'Left': 705.0,
#     'Top': 341.0,
#     'Height': 12.0,
#     'Width': 16.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 341.0},
#  {'LineText': '236.31',
#   'Words': [{'WordText': '236.31',
#     'Left': 674.0,
#     'Top': 409.0,
#     'Height': 14.0,
#     'Width': 46.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 409.0},
#  {'LineText': '31',
#   'Words': [{'WordText': '31',
#     'Left': 706.0,
#     'Top': 428.0,
#     'Height': 12.0,
#     'Width': 15.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 428.0},
#  {'LineText': '-77.38',
#   'Words': [{'WordText': '-77.38',
#     'Left': 674.0,
#     'Top': 444.0,
#     'Height': 14.0,
#     'Width': 47.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 444.0},
#  {'LineText': '$0.99',
#   'Words': [{'WordText': '$0.99',
#     'Left': 674.0,
#     'Top': 462.0,
#     'Height': 14.0,
#     'Width': 47.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 462.0},
#  {'LineText': '294.38',
#   'Words': [{'WordText': '294.38',
#     'Left': 673.0,
#     'Top': 480.0,
#     'Height': 13.0,
#     'Width': 48.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 480.0},
#  {'LineText': '30',
#   'Words': [{'WordText': '30',
#     'Left': 705.0,
#     'Top': 307.0,
#     'Height': 12.0,
#     'Width': 16.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 307.0},
#  {'LineText': '032784Kr oryPUbl CPYHTOBblE',
#   'Words': [{'WordText': '032784Kr',
#     'Left': 244.0,
#     'Top': 382.0,
#     'Height': 13.0,
#     'Width': 67.0},
#    {'WordText': 'oryPUbl',
#     'Left': 321.0,
#     'Top': 386.0,
#     'Height': 13.0,
#     'Width': 50.0},
#    {'WordText': 'CPYHTOBblE',
#     'Left': 380.0,
#     'Top': 384.0,
#     'Height': 14.0,
#     'Width': 74.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 382.0},
#  {'LineText': '066284Kr OPAHHEBblÉ1',
#   'Words': [{'WordText': '066284Kr',
#     'Left': 243.0,
#     'Top': 400.0,
#     'Height': 13.0,
#     'Width': 66.0},
#    {'WordText': 'OPAHHEBblÉ1',
#     'Left': 438.0,
#     'Top': 399.0,
#     'Height': 15.0,
#     'Width': 76.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 399.0},
#  {'LineText': '066061Kr nownOPbl HEPPi,1 P030BblE',
#   'Words': [{'WordText': '066061Kr',
#     'Left': 242.0,
#     'Top': 418.0,
#     'Height': 13.0,
#     'Width': 67.0},
#    {'WordText': 'nownOPbl',
#     'Left': 320.0,
#     'Top': 420.0,
#     'Height': 14.0,
#     'Width': 67.0},
#    {'WordText': 'HEPPi,1',
#     'Left': 396.0,
#     'Top': 421.0,
#     'Height': 13.0,
#     'Width': 41.0},
#    {'WordText': 'P030BblE',
#     'Left': 446.0,
#     'Top': 420.0,
#     'Height': 12.0,
#     'Width': 59.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 418.0},
#  {'LineText': '194296UT. MEJK)HA nvpny',
#   'Words': [{'WordText': '194296UT.',
#     'Left': 243.0,
#     'Top': 435.0,
#     'Height': 14.0,
#     'Width': 72.0},
#    {'WordText': 'MEJK)HA',
#     'Left': 412.0,
#     'Top': 438.0,
#     'Height': 13.0,
#     'Width': 50.0},
#    {'WordText': 'nvpny',
#     'Left': 471.0,
#     'Top': 438.0,
#     'Height': 12.0,
#     'Width': 42.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 435.0},
#  {'LineText': '081834LJT [M+]896S MOPOHEHOE',
#   'Words': [{'WordText': '081834LJT',
#     'Left': 241.0,
#     'Top': 452.0,
#     'Height': 14.0,
#     'Width': 67.0},
#    {'WordText': '[M+]896S',
#     'Left': 321.0,
#     'Top': 455.0,
#     'Height': 17.0,
#     'Width': 66.0},
#    {'WordText': 'MOPOHEHOE',
#     'Left': 395.0,
#     'Top': 456.0,
#     'Height': 13.0,
#     'Width': 75.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 452.0},
#  {'LineText': '167S06WT. MOPOHEHOE',
#   'Words': [{'WordText': '167S06WT.',
#     'Left': 241.0,
#     'Top': 470.0,
#     'Height': 15.0,
#     'Width': 73.0},
#    {'WordText': 'MOPOHEHOE',
#     'Left': 327.0,
#     'Top': 474.0,
#     'Height': 14.0,
#     'Width': 76.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 470.0},
#  {'LineText': '004031Kr nepeu KPACHb11%1 K',
#   'Words': [{'WordText': '004031Kr',
#     'Left': 238.0,
#     'Top': 488.0,
#     'Height': 14.0,
#     'Width': 69.0},
#    {'WordText': 'nepeu',
#     'Left': 317.0,
#     'Top': 491.0,
#     'Height': 15.0,
#     'Width': 43.0},
#    {'WordText': 'KPACHb11%1',
#     'Left': 437.0,
#     'Top': 490.0,
#     'Height': 16.0,
#     'Width': 59.0},
#    {'WordText': 'K',
#     'Left': 504.0,
#     'Top': 493.0,
#     'Height': 12.0,
#     'Width': 9.0}],
#   'MaxHeight': 16.0,
#   'MinTop': 488.0},
#  {'LineText': 'BAY*OBCKVIE onJlATbl',
#   'Words': [{'WordText': 'BAY*OBCKVIE',
#     'Left': 411.0,
#     'Top': 533.0,
#     'Height': 12.0,
#     'Width': 84.0},
#    {'WordText': 'onJlATbl',
#     'Left': 504.0,
#     'Top': 533.0,
#     'Height': 12.0,
#     'Width': 51.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 533.0},
#  {'LineText': '000 rp0AT0pr',
#   'Words': [{'WordText': '000',
#     'Left': 401.0,
#     'Top': 569.0,
#     'Height': 12.0,
#     'Width': 26.0},
#    {'WordText': 'rp0AT0pr',
#     'Left': 435.0,
#     'Top': 569.0,
#     'Height': 15.0,
#     'Width': 67.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 569.0},
#  {'LineText': 'r. rwv-wopcKH" xpag',
#   'Words': [{'WordText': 'r.',
#     'Left': 325.0,
#     'Top': 588.0,
#     'Height': 10.0,
#     'Width': 12.0},
#    {'WordText': 'rwv-wopcKH"',
#     'Left': 452.0,
#     'Top': 587.0,
#     'Height': 15.0,
#     'Width': 85.0},
#    {'WordText': 'xpag',
#     'Left': 546.0,
#     'Top': 588.0,
#     'Height': 15.0,
#     'Width': 34.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 587.0},
#  {'LineText': 'np-KT 100-neTHß BnaAHBOCTOKa',
#   'Words': [{'WordText': 'np-KT',
#     'Left': 332.0,
#     'Top': 607.0,
#     'Height': 12.0,
#     'Width': 41.0},
#    {'WordText': '100-neTHß',
#     'Left': 384.0,
#     'Top': 604.0,
#     'Height': 13.0,
#     'Width': 75.0},
#    {'WordText': 'BnaAHBOCTOKa',
#     'Left': 468.0,
#     'Top': 605.0,
#     'Height': 14.0,
#     'Width': 103.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 604.0},
#  {'LineText': 'A,68',
#   'Words': [{'WordText': 'A,68',
#     'Left': 433.0,
#     'Top': 623.0,
#     'Height': 14.0,
#     'Width': 35.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 623.0},
#  {'LineText': '07.25 11',
#   'Words': [{'WordText': '07.25',
#     'Left': 260.0,
#     'Top': 639.0,
#     'Height': 12.0,
#     'Width': 43.0},
#    {'WordText': '11',
#     'Left': 347.0,
#     'Top': 640.0,
#     'Height': 13.0,
#     'Width': 16.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 639.0},
#  {'LineText': 'nao C6EPbAHK',
#   'Words': [{'WordText': 'nao',
#     'Left': 233.0,
#     'Top': 657.0,
#     'Height': 12.0,
#     'Width': 26.0},
#    {'WordText': 'C6EPbAHK',
#     'Left': 268.0,
#     'Top': 657.0,
#     'Height': 13.0,
#     'Width': 69.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 657.0},
#  {'LineText': 'Tept.MHan: 32662488',
#   'Words': [{'WordText': 'Tept.MHan:',
#     'Left': 234.0,
#     'Top': 675.0,
#     'Height': 16.0,
#     'Width': 73.0},
#    {'WordText': '32662488',
#     'Left': 319.0,
#     'Top': 676.0,
#     'Height': 13.0,
#     'Width': 70.0}],
#   'MaxHeight': 16.0,
#   'MinTop': 675.0},
#  {'LineText': 'MIR',
#   'Words': [{'WordText': 'MIR',
#     'Left': 231.0,
#     'Top': 693.0,
#     'Height': 13.0,
#     'Width': 26.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 693.0},
#  {'LineText': '(E4) *5977',
#   'Words': [{'WordText': '(E4)',
#     'Left': 399.0,
#     'Top': 695.0,
#     'Height': 17.0,
#     'Width': 31.0},
#    {'WordText': '*5977',
#     'Left': 442.0,
#     'Top': 696.0,
#     'Height': 14.0,
#     'Width': 41.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 695.0},
#  {'LineText': 'CYMMa(PYO):',
#   'Words': [{'WordText': 'CYMMa(PYO):',
#     'Left': 230.0,
#     'Top': 712.0,
#     'Height': 17.0,
#     'Width': 93.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 712.0},
#  {'LineText': 'KOMHCCHR 3d onepaqs•tn O Py6.',
#   'Words': [{'WordText': 'KOMHCCHR',
#     'Left': 228.0,
#     'Top': 730.0,
#     'Height': 14.0,
#     'Width': 72.0},
#    {'WordText': '3d',
#     'Left': 309.0,
#     'Top': 734.0,
#     'Height': 11.0,
#     'Width': 17.0},
#    {'WordText': 'onepaqs•tn',
#     'Left': 335.0,
#     'Top': 735.0,
#     'Height': 14.0,
#     'Width': 70.0},
#    {'WordText': 'O',
#     'Left': 414.0,
#     'Top': 733.0,
#     'Height': 13.0,
#     'Width': 8.0},
#    {'WordText': 'Py6.',
#     'Left': 431.0,
#     'Top': 733.0,
#     'Height': 16.0,
#     'Width': 31.0}],
#   'MaxHeight': 16.0,
#   'MinTop': 730.0},
#  {'LineText': 'OL06PEHO',
#   'Words': [{'WordText': 'OL06PEHO',
#     'Left': 370.0,
#     'Top': 751.0,
#     'Height': 14.0,
#     'Width': 69.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 751.0},
#  {'LineText': 'HEK 0105',
#   'Words': [{'WordText': 'HEK',
#     'Left': 580.0,
#     'Top': 643.0,
#     'Height': 13.0,
#     'Width': 25.0},
#    {'WordText': '0105',
#     'Left': 631.0,
#     'Top': 644.0,
#     'Height': 13.0,
#     'Width': 33.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 643.0},
#  {'LineText': 'Onnara',
#   'Words': [{'WordText': 'Onnara',
#     'Left': 614.0,
#     'Top': 662.0,
#     'Height': 14.0,
#     'Width': 49.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 662.0},
#  {'LineText': ': 701000111801',
#   'Words': [{'WordText': ':',
#     'Left': 556.0,
#     'Top': 682.0,
#     'Height': 10.0,
#     'Width': 2.0},
#    {'WordText': '701000111801',
#     'Left': 562.0,
#     'Top': 680.0,
#     'Height': 14.0,
#     'Width': 101.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 680.0},
#  {'LineText': 'A0000006581010',
#   'Words': [{'WordText': 'A0000006581010',
#     'Left': 545.0,
#     'Top': 698.0,
#     'Height': 14.0,
#     'Width': 118.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 698.0},
#  {'LineText': '1545.28',
#   'Words': [{'WordText': '1545.28',
#     'Left': 605.0,
#     'Top': 718.0,
#     'Height': 13.0,
#     'Width': 58.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 718.0},
#  {'LineText': 'K/A: 059518',
#   'Words': [{'WordText': 'K/A:',
#     'Left': 224.0,
#     'Top': 767.0,
#     'Height': 14.0,
#     'Width': 34.0},
#    {'WordText': '059518',
#     'Left': 271.0,
#     'Top': 769.0,
#     'Height': 13.0,
#     'Width': 53.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 767.0},
#  {'LineText': 'RRN: 518755305974',
#   'Words': [{'WordText': 'RRN:',
#     'Left': 500.0,
#     'Top': 772.0,
#     'Height': 13.0,
#     'Width': 31.0},
#    {'WordText': '518755305974',
#     'Left': 561.0,
#     'Top': 773.0,
#     'Height': 14.0,
#     'Width': 101.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 772.0},
#  {'LineText': 'npoæpeH0 YCTpohCTBe KYIHeHTa',
#   'Words': [{'WordText': 'npoæpeH0',
#     'Left': 305.0,
#     'Top': 788.0,
#     'Height': 17.0,
#     'Width': 80.0},
#    {'WordText': 'YCTpohCTBe',
#     'Left': 421.0,
#     'Top': 790.0,
#     'Height': 16.0,
#     'Width': 87.0},
#    {'WordText': 'KYIHeHTa',
#     'Left': 517.0,
#     'Top': 794.0,
#     'Height': 11.0,
#     'Width': 60.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 788.0},
#  {'LineText': 'BS1807A736F7DFCEB9299FC8C9070488B3678198',
#   'Words': [{'WordText': 'BS1807A736F7DFCEB9299FC8C9070488B3678198',
#     'Left': 269.0,
#     'Top': 807.0,
#     'Height': 17.0,
#     'Width': 351.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 807.0},
#  {'LineText': '"Tor',
#   'Words': [{'WordText': '"Tor',
#     'Left': 223.0,
#     'Top': 866.0,
#     'Height': 13.0,
#     'Width': 35.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 866.0},
#  {'LineText': 'cytw',
#   'Words': [{'WordText': 'cytw',
#     'Left': 222.0,
#     'Top': 903.0,
#     'Height': 15.0,
#     'Width': 44.0}],
#   'MaxHeight': 15.0,
#   'MinTop': 903.0},
#  {'LineText': '-1545 28',
#   'Words': [{'WordText': '-1545',
#     'Left': 652.0,
#     'Top': 885.0,
#     'Height': 14.0,
#     'Width': 39.0},
#    {'WordText': '28',
#     'Left': 694.0,
#     'Top': 884.0,
#     'Height': 13.0,
#     'Width': 21.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 884.0},
#  {'LineText': '-155.38 CYMMA I-wc',
#   'Words': [{'WordText': '-155.38',
#     'Left': 408.0,
#     'Top': 904.0,
#     'Height': 14.0,
#     'Width': 61.0},
#    {'WordText': 'CYMMA',
#     'Left': 479.0,
#     'Top': 905.0,
#     'Height': 13.0,
#     'Width': 44.0},
#    {'WordText': 'I-wc',
#     'Left': 532.0,
#     'Top': 906.0,
#     'Height': 13.0,
#     'Width': 26.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 904.0},
#  {'LineText': 'Bbl',
#   'Words': [{'WordText': 'Bbl',
#     'Left': 221.0,
#     'Top': 949.0,
#     'Height': 29.0,
#     'Width': 22.0}],
#   'MaxHeight': 29.0,
#   'MinTop': 949.0},
#  {'LineText': 'cmacvi60 aa',
#   'Words': [{'WordText': 'cmacvi60',
#     'Left': 361.0,
#     'Top': 988.0,
#     'Height': 17.0,
#     'Width': 78.0},
#    {'WordText': 'aa',
#     'Left': 452.0,
#     'Top': 991.0,
#     'Height': 14.0,
#     'Width': 21.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 988.0},
#  {'LineText': 'Konvaqecmao HaxneeK 2 ,',
#   'Words': [{'WordText': 'Konvaqecmao',
#     'Left': 222.0,
#     'Top': 1028.0,
#     'Height': 16.0,
#     'Width': 114.0},
#    {'WordText': 'HaxneeK',
#     'Left': 349.0,
#     'Top': 1031.0,
#     'Height': 14.0,
#     'Width': 78.0},
#    {'WordText': '2',
#     'Left': 440.0,
#     'Top': 1031.0,
#     'Height': 15.0,
#     'Width': 10.0},
#    {'WordText': ',',
#     'Left': 489.0,
#     'Top': 1042.0,
#     'Height': 4.0,
#     'Width': 2.0}],
#   'MaxHeight': 16.0,
#   'MinTop': 1028.0},
#  {'LineText': 'Baue',
#   'Words': [{'WordText': 'Baue',
#     'Left': 221.0,
#     'Top': 1064.0,
#     'Height': 13.0,
#     'Width': 35.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 1064.0},
#  {'LineText': 'O Oonycop',
#   'Words': [{'WordText': 'O',
#     'Left': 397.0,
#     'Top': 1083.0,
#     'Height': 12.0,
#     'Width': 8.0},
#    {'WordText': 'Oonycop',
#     'Left': 414.0,
#     'Top': 1084.0,
#     'Height': 14.0,
#     'Width': 60.0}],
#   'MaxHeight': 14.0,
#   'MinTop': 1083.0},
#  {'LineText': 'Bam 46.4 Oonycoe',
#   'Words': [{'WordText': 'Bam',
#     'Left': 221.0,
#     'Top': 1099.0,
#     'Height': 12.0,
#     'Width': 27.0},
#    {'WordText': '46.4',
#     'Left': 344.0,
#     'Top': 1099.0,
#     'Height': 13.0,
#     'Width': 34.0},
#    {'WordText': 'Oonycoe',
#     'Left': 388.0,
#     'Top': 1100.0,
#     'Height': 13.0,
#     'Width': 59.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 1099.0},
#  {'LineText': 'Y Bac 0.0',
#   'Words': [{'WordText': 'Y',
#     'Left': 222.0,
#     'Top': 1116.0,
#     'Height': 12.0,
#     'Width': 8.0},
#    {'WordText': 'Bac',
#     'Left': 239.0,
#     'Top': 1116.0,
#     'Height': 11.0,
#     'Width': 26.0},
#    {'WordText': '0.0',
#     'Left': 344.0,
#     'Top': 1116.0,
#     'Height': 11.0,
#     'Width': 26.0}],
#   'MaxHeight': 12.0,
#   'MinTop': 1116.0},
#  {'LineText': 'KAUMP',
#   'Words': [{'WordText': 'KAUMP',
#     'Left': 222.0,
#     'Top': 1132.0,
#     'Height': 11.0,
#     'Width': 52.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 1132.0},
#  {'LineText': 'Gi-iC Jog. qov. ru',
#   'Words': [{'WordText': 'Gi-iC',
#     'Left': 266.0,
#     'Top': 1147.0,
#     'Height': 10.0,
#     'Width': 25.0},
#    {'WordText': 'Jog.',
#     'Left': 377.0,
#     'Top': 1145.0,
#     'Height': 12.0,
#     'Width': 28.0},
#    {'WordText': 'qov.',
#     'Left': 410.0,
#     'Top': 1145.0,
#     'Height': 17.0,
#     'Width': 29.0},
#    {'WordText': 'ru',
#     'Left': 444.0,
#     'Top': 1144.0,
#     'Height': 8.0,
#     'Width': 16.0}],
#   'MaxHeight': 17.0,
#   'MinTop': 1144.0},
#  {'LineText': 'MECVO PACHEIOB',
#   'Words': [{'WordText': 'MECVO',
#     'Left': 223.0,
#     'Top': 1161.0,
#     'Height': 10.0,
#     'Width': 43.0},
#    {'WordText': 'PACHEIOB',
#     'Left': 275.0,
#     'Top': 1160.0,
#     'Height': 11.0,
#     'Width': 68.0}],
#   'MaxHeight': 11.0,
#   'MinTop': 1160.0},
#  {'LineText': 'KACCA 0002.01 CHEHA 0602b ii:S3',
#   'Words': [{'WordText': 'KACCA',
#     'Left': 224.0,
#     'Top': 1175.0,
#     'Height': 9.0,
#     'Width': 42.0},
#    {'WordText': '0002.01',
#     'Left': 275.0,
#     'Top': 1174.0,
#     'Height': 10.0,
#     'Width': 59.0},
#    {'WordText': 'CHEHA',
#     'Left': 344.0,
#     'Top': 1173.0,
#     'Height': 11.0,
#     'Width': 41.0},
#    {'WordText': '0602b',
#     'Left': 437.0,
#     'Top': 1166.0,
#     'Height': 13.0,
#     'Width': 65.0},
#    {'WordText': 'ii:S3',
#     'Left': 512.0,
#     'Top': 1163.0,
#     'Height': 12.0,
#     'Width': 39.0}],
#   'MaxHeight': 13.0,
#   'MinTop': 1163.0},
#  {'LineText': 'CHO OCH',
#   'Words': [{'WordText': 'CHO',
#     'Left': 225.0,
#     'Top': 1188.0,
#     'Height': 9.0,
#     'Width': 25.0},
#    {'WordText': 'OCH',
#     'Left': 259.0,
#     'Top': 1188.0,
#     'Height': 9.0,
#     'Width': 25.0}],
#   'MaxHeight': 9.0,
#   'MinTop': 1188.0},
#  {'LineText': '12Baoe',
#   'Words': [{'WordText': '12Baoe',
#     'Left': 252.0,
#     'Top': 1200.0,
#     'Height': 9.0,
#     'Width': 49.0}],
#   'MaxHeight': 9.0,
#   'MinTop': 1200.0},
#  {'LineText': "0007514•a0Gocz.oG evil-' i 1571",
#   'Words': [{'WordText': '0007514•a0Gocz.oG',
#     'Left': 282.0,
#     'Top': 1222.0,
#     'Height': 10.0,
#     'Width': 131.0},
#    {'WordText': "evil-'",
#     'Left': 434.0,
#     'Top': 1220.0,
#     'Height': 10.0,
#     'Width': 24.0},
#    {'WordText': 'i',
#     'Left': 505.0,
#     'Top': 1217.0,
#     'Height': 9.0,
#     'Width': 5.0},
#    {'WordText': '1571',
#     'Left': 513.0,
#     'Top': 1216.0,
#     'Height': 9.0,
#     'Width': 29.0}],
#   'MaxHeight': 10.0,
#   'MinTop': 1216.0}]

# %%
import vk_api
from vk_api.bot_longpoll import VkBotLongPoll, VkBotEventType
import requests
import os
# Инициализация с использованием токена сообщества
VK_TOKEN = os.getenv("vk_api")
vk_session = vk_api.VkApi(token=VK_TOKEN)
longpoll = VkBotLongPoll(vk_session, group_id=231492060)  # укажите ID группы числом
vk = vk_session.get_api()  # объект для вызова методов VK API

# Хранилище данных пользователей
user_data = {}  # словарь {user_id: {"name": ..., "phone": ..., "bank": ...}}
user_state = {}  # словарь для отслеживания этапа регистрации {user_id: "awaiting_name"/"awaiting_phone"/...}

# %%
def handle_personal_message(user_id, message_text):
    """Обработка личного сообщения от пользователя (регистрация)."""
    # Если пользователь еще не начал регистрацию, либо явно ввел команду "/start"
    if user_id not in user_data or message_text.lower() == "/start":
        user_state[user_id] = "awaiting_name"
        vk.messages.send(
            user_id=user_id,
            message="Здравствуйте! Для регистрации в системе разделения счетов введите, пожалуйста, свое ФИО.",
            random_id=0
        )
        return

    # Если ожидаем ввод ФИО
    if user_state.get(user_id) == "awaiting_name":
        # Сохраняем ФИО и переходим к следующему шагу
        full_name = message_text.strip()
        user_data[user_id] = {"name": full_name}
        user_state[user_id] = "awaiting_phone"
        vk.messages.send(
            user_id=user_id,
            message=f"Спасибо, {full_name}! Теперь отправьте номер телефона, привязанный к вашему банковскому аккаунту (для переводов).",
            random_id=0
        )
        return

    # Если ожидаем ввод телефона
    if user_state.get(user_id) == "awaiting_phone":
        phone = message_text.strip()
        user_data[user_id]["phone"] = phone
        user_state[user_id] = "awaiting_bank"
        vk.messages.send(
            user_id=user_id,
            message="Отлично. Укажите предпочтительный банк для переводов (например, Сбербанк, Тинькофф и т.д.).",
            random_id=0
        )
        return

    # Если ожидаем ввод банка
    if user_state.get(user_id) == "awaiting_bank":
        bank = message_text.strip()
        user_data[user_id]["bank"] = bank
        user_state[user_id] = None  # регистрация завершена
        vk.messages.send(
            user_id=user_id,
            message=f"Вы успешно зарегистрированы! ФИО: {user_data[user_id]['name']}, Телефон: {user_data[user_id]['phone']}, Банк: {user_data[user_id]['bank']}.",
            random_id=0
        )
        # Опционально: уведомить, что теперь можно добавлять бота в беседы
        vk.messages.send(
            user_id=user_id,
            message="Теперь вы можете добавить бота в беседу для разделения счетов.",
            random_id=0
        )
        return

# %%
"""Пример минимального бота ВКонтакте, который отвечает пользователям
личным сообщением. Подготовлен для python-vk_api >= 11.9.
"""
import os
import vk_api
from vk_api.bot_longpoll import VkBotLongPoll, VkBotEventType
from vk_api.utils import get_random_id

VK_TOKEN = os.getenv("vk_api")  # Токен сообщества в переменных окружения
GROUP_ID = 231492060  # ID вашего сообщества

# Инициализируем сессию и объекты API
vk_session = vk_api.VkApi(token=VK_TOKEN)
longpoll = VkBotLongPoll(vk_session, group_id=GROUP_ID)
vk = vk_session.get_api()

# Простейшие хранилища, если понадобится сохранять данные о пользователях
user_data = {}
user_state = {}

def send_private_message(user_id: int, text: str) -> None:
    """Отправляет личное сообщение пользователю от имени сообщества."""
    vk.messages.send(
        peer_id=user_id,             # Для личного сообщения достаточно ID пользователя
        random_id=get_random_id(),   # Уникальный random_id предотвращает дубли
        message=text
    )

def main() -> None:
    print("Bot started — listening for events…")
    for event in longpoll.listen():
        # Отслеживаем входящие личные сообщения пользователям
        if event.type == VkBotEventType.MESSAGE_NEW and event.from_user:
            user_id = event.message["from_id"]
            text = event.message.get("text", "").strip().lower()

            if text == "/start":
                send_private_message(user_id, "Привет! Я бот и теперь могу писать в личку 😉")
            else:
                send_private_message(user_id, f"Вы написали: {text or '...' }")

if __name__ == "__main__":
    main()
# Out:
# Bot started — listening for events…

# %%
vk.messages.send(
    peer_id=user_id,          # личка
    random_id=get_random_id(),
    message="123"
)

# %%
""
